# %%
import requests
import pandas as pd
import time
import os
import json

# %%
# Download Data
# the results will be stored in the folder "data"
# the folder structure should be:
# project-chaggg/
# ├── data/
# │   └── chicago_crime_data/
# │       ├── batches/
# │       └── chicago_crimes_2001_2025.csv

# ── Config ────────────────────────────────────────────────────────────────────
APP_TOKEN    = "YOUR TOKEN HERE"
BASE_URL     = "https://data.cityofchicago.org/resource/ijzp-q8t2.json"
BATCH_SIZE   = 10000
BASE_DIR = os.getcwd()
OUTPUT_DIR   = os.path.join(BASE_DIR, "data", "chicago_crime_data")
FINAL_OUTPUT = os.path.join(OUTPUT_DIR, "chicago_crimes_2001_2025.csv")
PROGRESS_FILE = os.path.join(OUTPUT_DIR, "progress.json")
BATCH_DIR = os.path.join(OUTPUT_DIR, "batches") # this line was not in the last version
os.makedirs(BATCH_DIR, exist_ok=True)

EXPECTED_COLUMNS = [
    'id', 'case_number', 'date', 'block', 'iucr', 'primary_type',
    'description', 'location_description', 'arrest', 'domestic', 'beat',
    'district', 'ward', 'community_area', 'fbi_code', 'year', 'updated_on',
    'x_coordinate', 'y_coordinate', 'latitude', 'longitude', 'location'
]

# ── Progress helpers ──────────────────────────────────────────────────────────
def load_progress():
    if os.path.exists(PROGRESS_FILE):
        with open(PROGRESS_FILE) as f:
            return json.load(f)
    return {"offset": 0, "batch_num": 1, "total_records": 0}

def save_progress(offset, batch_num, total):
    with open(PROGRESS_FILE, "w") as f:
        json.dump({"offset": offset, "batch_num": batch_num, "total_records": total}, f)

# ── Fetch ─────────────────────────────────────────────────────────────────────
def fetch_batch(offset, retries=3):
    params = {
        "$limit":      BATCH_SIZE,
        "$offset":     offset,
        "$order":      "date ASC",
        "$$app_token": APP_TOKEN
    }
    for attempt in range(1, retries + 1):
        try:
            r = requests.get(BASE_URL, params=params, timeout=60)
            r.raise_for_status()
            return r.json()
        except requests.RequestException as e:
            print(f"  [Attempt {attempt}/{retries}] Failed: {e}")
            if attempt < retries:
                time.sleep(5 * attempt)
            else:
                raise

# ── Align columns ─────────────────────────────────────────────────────────────
def align_columns(df):
    for col in EXPECTED_COLUMNS:
        if col not in df.columns:
            df[col] = None
    return df[EXPECTED_COLUMNS]

# ── Download ──────────────────────────────────────────────────────────────────
def download_all():
    if os.path.exists(FINAL_OUTPUT):
        print(f"File already exists: {FINAL_OUTPUT}\nDownload skipped.")
        return
    progress  = load_progress()
    offset    = progress["offset"]
    batch_num = progress["batch_num"]
    total     = progress["total_records"]

    print(f"{'Resuming' if offset > 0 else 'Starting'} download "
          f"(batch={batch_num}, offset={offset}, saved={total})\n")

    while True:
        batch_file = os.path.join(BATCH_DIR, f"batch_{batch_num:04d}.csv")

        if os.path.exists(batch_file):
            print(f"Batch {batch_num} already exists, skipping...")
            offset    += BATCH_SIZE
            batch_num += 1
            continue

        print(f"Fetching batch {batch_num} (offset={offset})...")
        batch = fetch_batch(offset)

        if not batch:
            print("No more data. Download complete.")
            break

        df = align_columns(pd.DataFrame(batch))
        df.to_csv(batch_file, index=False)

        total     += len(batch)
        offset    += BATCH_SIZE
        batch_num += 1
        save_progress(offset, batch_num, total)
        print(f"  -> {len(batch)} records. Total: {total}")
        time.sleep(0.5)

    if os.path.exists(PROGRESS_FILE):
        os.remove(PROGRESS_FILE)

# ── Stream-merge batches ──────────────────────────────────────────────────────
def combine_batches():
    if os.path.exists(FINAL_OUTPUT):
        print(f"Final file already exists: {FINAL_OUTPUT}, skipping merge.")
        return

    batch_files = sorted(
        os.path.join(BATCH_DIR, f)
        for f in os.listdir(BATCH_DIR) if f.endswith(".csv")
    )
    print(f"\nMerging {len(batch_files)} batches into final CSV...")

    with open(FINAL_OUTPUT, "w", encoding="utf-8") as out:
        for i, path in enumerate(batch_files):
            df = pd.read_csv(path, low_memory=False)
            df = align_columns(df)                      # re-align just in case
            df.to_csv(out, index=False, header=(i == 0))
            print(f"  Merged {path} ({len(df)} rows)")

    print(f"\nDone! Saved to: {FINAL_OUTPUT}")

# ── Entry point ───────────────────────────────────────────────────────────────
if __name__ == "__main__":
    download_all()
    combine_batches()
# Out:
# Resuming download (batch=287, offset=7980000, saved=7980000)
#
# Fetching batch 287 (offset=7980000)...
#   -> 10000 records. Total: 7990000
# Fetching batch 288 (offset=7990000)...
#   -> 10000 records. Total: 8000000
# Fetching batch 289 (offset=8000000)...
#   -> 10000 records. Total: 8010000
# Fetching batch 290 (offset=8010000)...
#   -> 10000 records. Total: 8020000
# Fetching batch 291 (offset=8020000)...
#   -> 10000 records. Total: 8030000
# Fetching batch 292 (offset=8030000)...
#   -> 10000 records. Total: 8040000
# Fetching batch 293 (offset=8040000)...
#   -> 10000 records. Total: 8050000
# Fetching batch 294 (offset=8050000)...
#   -> 10000 records. Total: 8060000
# Fetching batch 295 (offset=8060000)...
#   -> 10000 records. Total: 8070000
# Fetching batch 296 (offset=8070000)...
#   -> 10000 records. Total: 8080000
# Fetching batch 297 (offset=8080000)...
#   -> 10000 records. Total: 8090000
# Fetching batch 298 (offset=8090000)...
#   -> 10000 records. Total: 8100000
# Fetching batch 299 (offset=8100000)...
#   -> 10000 records. Total: 8110000
# Fetching batch 300 (offset=8110000)...
#   [Attempt 1/3] Failed: HTTPSConnectionPool(host='data.cityofchicago.org', port=443): Read timed out. (read timeout=60)
#   [Attempt 2/3] Failed: HTTPSConnectionPool(host='data.cityofchicago.org', port=443): Read timed out. (read timeout=60)
#   -> 10000 records. Total: 8120000
# Fetching batch 301 (offset=8120000)...
#   -> 10000 records. Total: 8130000
# Fetching batch 302 (offset=8130000)...
#   -> 10000 records. Total: 8140000
# Fetching batch 303 (offset=8140000)...
#   -> 10000 records. Total: 8150000
# Fetching batch 304 (offset=8150000)...
#   -> 10000 records. Total: 8160000
# Fetching batch 305 (offset=8160000)...
#   -> 10000 records. Total: 8170000
# Fetching batch 306 (offset=8170000)...
#   -> 10000 records. Total: 8180000
# Fetching batch 307 (offset=8180000)...
#   -> 10000 records. Total: 8190000
# Fetching batch 308 (offset=8190000)...
#   -> 10000 records. Total: 8200000
# Fetching batch 309 (offset=8200000)...
#   -> 10000 records. Total: 8210000
# Fetching batch 310 (offset=8210000)...
#   [Attempt 1/3] Failed: HTTPSConnectionPool(host='data.cityofchicago.org', port=443): Read timed out. (read timeout=60)
#   -> 10000 records. Total: 8220000
# Fetching batch 311 (offset=8220000)...
#   -> 10000 records. Total: 8230000
# Fetching batch 312 (offset=8230000)...
#   -> 10000 records. Total: 8240000
# Fetching batch 313 (offset=8240000)...
#   -> 10000 records. Total: 8250000
# Fetching batch 314 (offset=8250000)...
#   -> 10000 records. Total: 8260000
# Fetching batch 315 (offset=8260000)...
#   -> 10000 records. Total: 8270000
# Fetching batch 316 (offset=8270000)...
#   -> 10000 records. Total: 8280000
# Fetching batch 317 (offset=8280000)...
#   -> 10000 records. Total: 8290000
# Fetching batch 318 (offset=8290000)...
#   -> 10000 records. Total: 8300000
# Fetching batch 319 (offset=8300000)...
#   -> 10000 records. Total: 8310000
# Fetching batch 320 (offset=8310000)...
#   -> 10000 records. Total: 8320000
# Fetching batch 321 (offset=8320000)...
#   -> 10000 records. Total: 8330000
# Fetching batch 322 (offset=8330000)...
#   -> 10000 records. Total: 8340000
# Fetching batch 323 (offset=8340000)...
#   -> 10000 records. Total: 8350000
# Fetching batch 324 (offset=8350000)...
#   -> 10000 records. Total: 8360000
# Fetching batch 325 (offset=8360000)...
#   -> 10000 records. Total: 8370000
# Fetching batch 326 (offset=8370000)...
#   -> 10000 records. Total: 8380000
# Fetching batch 327 (offset=8380000)...
#   -> 10000 records. Total: 8390000
# Fetching batch 328 (offset=8390000)...
#   -> 10000 records. Total: 8400000
# Fetching batch 329 (offset=8400000)...
#   -> 10000 records. Total: 8410000
# Fetching batch 330 (offset=8410000)...
#   -> 10000 records. Total: 8420000
# Fetching batch 331 (offset=8420000)...
#   -> 10000 records. Total: 8430000
# Fetching batch 332 (offset=8430000)...
#   -> 10000 records. Total: 8440000
# Fetching batch 333 (offset=8440000)...
#   -> 10000 records. Total: 8450000
# Fetching batch 334 (offset=8450000)...
#   [Attempt 1/3] Failed: HTTPSConnectionPool(host='data.cityofchicago.org', port=443): Read timed out. (read timeout=60)
#   -> 10000 records. Total: 8460000
# Fetching batch 335 (offset=8460000)...
#   [Attempt 1/3] Failed: HTTPSConnectionPool(host='data.cityofchicago.org', port=443): Read timed out. (read timeout=60)
#   [Attempt 2/3] Failed: HTTPSConnectionPool(host='data.cityofchicago.org', port=443): Read timed out. (read timeout=60)
#   -> 10000 records. Total: 8470000
# Fetching batch 336 (offset=8470000)...
#   -> 10000 records. Total: 8480000
# Fetching batch 337 (offset=8480000)...
#   -> 10000 records. Total: 8490000
# Fetching batch 338 (offset=8490000)...
#   -> 10000 records. Total: 8500000
# Fetching batch 339 (offset=8500000)...
#   [Attempt 1/3] Failed: HTTPSConnectionPool(host='data.cityofchicago.org', port=443): Read timed out. (read timeout=60)
#   [Attempt 2/3] Failed: HTTPSConnectionPool(host='data.cityofchicago.org', port=443): Read timed out. (read timeout=60)
#   -> 10000 records. Total: 8510000
# Fetching batch 340 (offset=8510000)...
#   -> 10000 records. Total: 8520000
# Fetching batch 341 (offset=8520000)...
#   -> 8110 records. Total: 8528110
# Fetching batch 342 (offset=8530000)...
# No more data. Download complete.
#
# Merging 341 batches into final CSV...
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0001.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0002.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0003.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0004.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0005.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0006.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0007.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0008.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0009.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0010.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0011.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0012.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0013.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0014.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0015.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0016.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0017.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0018.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0019.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0020.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0021.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0022.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0023.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0024.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0025.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0026.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0027.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0028.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0029.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0030.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0031.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0032.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0033.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0034.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0035.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0036.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0037.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0038.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0039.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0040.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0041.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0042.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0043.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0044.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0045.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0046.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0047.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0048.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0049.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0050.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0051.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0052.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0053.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0054.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0055.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0056.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0057.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0058.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0059.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0060.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0061.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0062.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0063.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0064.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0065.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0066.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0067.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0068.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0069.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0070.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0071.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0072.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0073.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0074.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0075.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0076.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0077.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0078.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0079.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0080.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0081.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0082.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0083.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0084.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0085.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0086.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0087.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0088.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0089.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0090.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0091.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0092.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0093.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0094.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0095.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0096.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0097.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0098.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0099.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0100.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0101.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0102.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0103.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0104.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0105.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0106.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0107.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0108.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0109.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0110.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0111.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0112.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0113.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0114.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0115.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0116.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0117.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0118.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0119.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0120.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0121.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0122.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0123.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0124.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0125.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0126.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0127.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0128.csv (50000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0129.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0130.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0131.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0132.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0133.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0134.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0135.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0136.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0137.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0138.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0139.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0140.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0141.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0142.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0143.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0144.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0145.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0146.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0147.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0148.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0149.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0150.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0151.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0152.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0153.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0154.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0155.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0156.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0157.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0158.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0159.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0160.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0161.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0162.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0163.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0164.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0165.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0166.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0167.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0168.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0169.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0170.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0171.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0172.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0173.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0174.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0175.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0176.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0177.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0178.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0179.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0180.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0181.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0182.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0183.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0184.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0185.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0186.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0187.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0188.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0189.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0190.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0191.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0192.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0193.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0194.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0195.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0196.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0197.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0198.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0199.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0200.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0201.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0202.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0203.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0204.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0205.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0206.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0207.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0208.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0209.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0210.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0211.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0212.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0213.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0214.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0215.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0216.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0217.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0218.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0219.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0220.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0221.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0222.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0223.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0224.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0225.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0226.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0227.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0228.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0229.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0230.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0231.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0232.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0233.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0234.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0235.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0236.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0237.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0238.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0239.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0240.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0241.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0242.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0243.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0244.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0245.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0246.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0247.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0248.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0249.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0250.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0251.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0252.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0253.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0254.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0255.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0256.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0257.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0258.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0259.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0260.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0261.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0262.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0263.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0264.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0265.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0266.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0267.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0268.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0269.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0270.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0271.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0272.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0273.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0274.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0275.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0276.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0277.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0278.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0279.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0280.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0281.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0282.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0283.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0284.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0285.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0286.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0287.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0288.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0289.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0290.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0291.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0292.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0293.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0294.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0295.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0296.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0297.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0298.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0299.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0300.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0301.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0302.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0303.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0304.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0305.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0306.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0307.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0308.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0309.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0310.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0311.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0312.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0313.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0314.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0315.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0316.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0317.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0318.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0319.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0320.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0321.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0322.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0323.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0324.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0325.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0326.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0327.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0328.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0329.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0330.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0331.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0332.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0333.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0334.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0335.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0336.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0337.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0338.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0339.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0340.csv (10000 rows)
#   Merged /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/batches/batch_0341.csv (8110 rows)
#
# Done! Saved to: /Users/gracewang/Documents/Hertie/Data Structures & Algorithms/project-chaggg/notebooks/data/chicago_crime_data/chicago_crimes_2001_2025.csv

# %%
# Load the data

df = pd.read_csv("data/chicago_crime_data/chicago_crimes_2001_2025.csv", low_memory = False)
# Out:
# ---------------------------------------------------------------------------
#
# FileNotFoundError                         Traceback (most recent call last)
#
# Cell In[12], line 3
#
#       1 # Load the data
#
# ----> 3 df = pd.read_csv("data/chicago_crime_data/chicago_crimes_2001_2025.csv", low_memory = False)
#
#
#
# File ~/Documents/Hertie/Data Structures & Algorithms/project-chaggg/.venv/lib/python3.14/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#
#     861 kwds_defaults = _refine_defaults_read(
#
#     862     dialect,
#
#     863     delimiter,
#
#    (...)
#
#     869     dtype_backend=dtype_backend,
#
#     870 )
#
#     871 kwds.update(kwds_defaults)
#
# --> 873 return _read(filepath_or_buffer, kwds)
#
#
#
# File ~/Documents/Hertie/Data Structures & Algorithms/project-chaggg/.venv/lib/python3.14/site-packages/pandas/io/parsers/readers.py:300, in _read(filepath_or_buffer, kwds)
#
#     297 _validate_names(kwds.get("names", None))
#
#     299 # Create the parser.
#
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#
#     302 if chunksize or iterator:
#
#     303     return parser
#
#
#
# File ~/Documents/Hertie/Data Structures & Algorithms/project-chaggg/.venv/lib/python3.14/site-packages/pandas/io/parsers/readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#
#    1644 self.handles: IOHandles | None = None
#
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
#
#
# File ~/Documents/Hertie/Data Structures & Algorithms/project-chaggg/.venv/lib/python3.14/site-packages/pandas/io/parsers/readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#
#    1902     if "b" not in mode:
#
#    1903         mode += "b"
#
# -> 1904 self.handles = get_handle(
#
#    1905     f,
#
#    1906     mode,
#
#    1907     encoding=self.options.get("encoding", None),
#
#    1908     compression=self.options.get("compression", None),
#
#    1909     memory_map=self.options.get("memory_map", False),
#
#    1910     is_text=is_text,
#
#    1911     errors=self.options.get("encoding_errors", "strict"),
#
#    1912     storage_options=self.options.get("storage_options", None),
#
#    1913 )
#
#    1914 assert self.handles is not None
#
#    1915 f = self.handles.handle
#
#
#
# File ~/Documents/Hertie/Data Structures & Algorithms/project-chaggg/.venv/lib/python3.14/site-packages/pandas/io/common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#
#     921 elif isinstance(handle, str):
#
#     922     # Check whether the filename is to be opened in binary mode.
#
#     923     # Binary mode does not support 'encoding' and 'newline'.
#
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#
#     925         # Encoding
#
# --> 926         handle = open(
#
#     927             handle,
#
#     928             ioargs.mode,
#
#     929             encoding=ioargs.encoding,
#
#     930             errors=errors,
#
#     931             newline="",
#
#     932         )
#
#     933     else:
#
#     934         # Binary mode
#
#     935         handle = open(handle, ioargs.mode)
#
#
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/chicago_crime_data/chicago_crimes_2001_2025.csv'

# %%
# Check the basic info of data

print(df.describe())
print(df.shape)          # rows and columns
print(df.dtypes)         # data types
print(df.columns.tolist()) # column names
# Out:
#                  id          beat      district          ward  community_area  \
# count  8.528110e+06  8.528110e+06  8.528063e+06  7.913294e+06    7.914383e+06
# mean   7.596738e+06  1.183081e+03  1.129540e+01  2.278803e+01    3.736448e+01
# std    3.827324e+06  7.038064e+02  6.965143e+00  1.385988e+01    2.154614e+01
# min    6.340000e+02  1.110000e+02  1.000000e+00  1.000000e+00    0.000000e+00
# 25%    4.116992e+06  6.210000e+02  6.000000e+00  1.000000e+01    2.300000e+01
# 50%    7.594692e+06  1.034000e+03  1.000000e+01  2.300000e+01    3.200000e+01
# 75%    1.102799e+07  1.731000e+03  1.700000e+01  3.400000e+01    5.600000e+01
# max    1.416048e+07  2.535000e+03  3.100000e+01  5.000000e+01    7.700000e+01
#
#                year  x_coordinate  y_coordinate      latitude     longitude
# count  8.528110e+06  8.431840e+06  8.431840e+06  8.431840e+06  8.431840e+06
# mean   2.011183e+03  1.164669e+06  1.885929e+06  4.184258e+01 -8.767124e+01
# std    7.208601e+00  1.694411e+04  3.241814e+04  8.919270e-02  6.140625e-02
# min    2.001000e+03  0.000000e+00  0.000000e+00  3.661945e+01 -9.168657e+01
# 25%    2.005000e+03  1.153093e+06  1.859222e+06  4.176900e+01 -8.771324e+01
# 50%    2.010000e+03  1.166225e+06  1.891038e+06  4.185669e+01 -8.766548e+01
# 75%    2.017000e+03  1.176406e+06  1.909413e+06  4.190710e+01 -8.762806e+01
# max    2.026000e+03  1.205119e+06  1.951622e+06  4.202291e+01 -8.752453e+01
# (8528110, 22)
# id                        int64
# case_number                 str
# date                        str
# block                       str
# iucr                        str
# primary_type                str
# description                 str
# location_description        str
# arrest                     bool
# domestic                   bool
# beat                      int64
# district                float64
# ward                    float64
# community_area          float64
# fbi_code                    str
# year                      int64
# updated_on                  str
# x_coordinate            float64
# y_coordinate            float64
# latitude                float64
# longitude               float64
# location                    str
# dtype: object
# ['id', 'case_number', 'date', 'block', 'iucr', 'primary_type', 'description', 'location_description', 'arrest', 'domestic', 'beat', 'district', 'ward', 'community_area', 'fbi_code', 'year', 'updated_on', 'x_coordinate', 'y_coordinate', 'latitude', 'longitude', 'location']

# %%
# Filter the data from 2001 to 2025

df = pd.read_csv(FINAL_OUTPUT, low_memory=False)
df = df[df['year'].between(2001, 2025)]
df.to_csv(FINAL_OUTPUT, index=False)
print(df['year'].value_counts().sort_index())
print(f"\nTotal records (2001-2025): {len(df)}")
# Out:
# year
# 2001    485958
# 2002    486831
# 2003    475999
# 2004    469443
# 2005    453788
# 2006    448198
# 2007    437108
# 2008    427216
# 2009    392866
# 2010    370566
# 2011    352052
# 2012    336374
# 2013    307612
# 2014    275880
# 2015    264887
# 2016    269959
# 2017    269286
# 2018    269147
# 2019    261702
# 2020    212700
# 2021    209656
# 2022    239999
# 2023    263278
# 2024    259007
# 2025    236558
# Name: count, dtype: int64
#
# Total records (2001-2025): 8476070

# %%
# Check missing data

missing = df.isnull().sum()
missing_pct = (missing / len(df) * 100).round(2)

missing_summary = pd.DataFrame({
    "missing_count": missing,
    "missing_pct": missing_pct
}).sort_values("missing_pct", ascending=False)

missing_summary
# Out:
#                       missing_count  missing_pct
# ward                         614816         7.21
# community_area               613727         7.20
# location                      96270         1.13
# longitude                     96270         1.13
# latitude                      96270         1.13
# y_coordinate                  96270         1.13
# x_coordinate                  96270         1.13
# location_description          15841         0.19
# updated_on                        0         0.00
# year                              0         0.00
# fbi_code                          0         0.00
# id                                0         0.00
# case_number                       0         0.00
# beat                              0         0.00
# domestic                          0         0.00
# arrest                            0         0.00
# description                       0         0.00
# primary_type                      0         0.00
# iucr                              0         0.00
# block                             0         0.00
# date                              0         0.00
# district                         47         0.00

# %% [markdown]
# ## Column Alignment Check
#
# All 22 columns are present and correctly ordered — no misalignment detected.
#
# Missing values are due to **genuine data gaps**, not structural issues:
#
# | Column | Missing | Reason |
# |--------|---------|--------|
# | `ward` / `community_area` | ~614k | Early records do not include these fields |
# | `x/y_coordinate` / `latitude` / `longitude` / `location` | ~94k | Addresses that could not be geocoded |
# | `location_description` | ~15k | Small number of records with no venue description |
# | `district` | 47 | Negligible |
