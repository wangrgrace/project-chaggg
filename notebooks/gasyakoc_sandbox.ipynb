# %% [markdown]
# # Gasya's Sandbox
# Personal notebook for Chicago Crime Analysis project.
# EDA visualizations will be developed here before moving to src/.

# %%
# Placeholder — will add analysis once cleaned data is available
print("Ready for EDA")
