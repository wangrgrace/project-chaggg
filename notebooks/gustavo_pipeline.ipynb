# %%
from src.preprocess_data import preprocess_data

# %%
final = preprocess_data()
# Out:
# Loading from c:\Users\gus7h\OneDrive\Documents\Hertie\2025-2026\Data Structures and Algorithms\project-chaggg\data\cleaned\chicago_crimes_cleaned.parquet...

# %%
final.columns
# Out:
# Index(['case_number', 'id', 'date', 'block', 'iucr', 'primary_type',
#        'description', 'location_description', 'domestic', 'beat', 'district',
#        'ward', 'community_area', 'fbi_code', 'year', 'updated_on',
#        'x_coordinate', 'y_coordinate', 'latitude', 'longitude', 'time',
#        'month', 'day', 'day_of_week', 'day_of_year', 'hour', 'minute',
#        'hour_sin', 'hour_cos', 'day_of_week_sin', 'day_of_week_cos',
#        'month_sin', 'month_cos', 'day_of_year_sin', 'day_of_year_cos',
#        'at_least_one_arrested', 'people_involved', 'arrest'],
#       dtype='str')

# %%
from src.crime_knn import select_crime

theft_df = select_crime(crime = "THEFT")
theft_df.columns
# Out:
# Loading from c:\Users\gus7h\OneDrive\Documents\Hertie\2025-2026\Data Structures and Algorithms\project-chaggg\data\cleaned\chicago_crimes_cleaned.parquet...
# Filter applied.
# 1680404 observations found for selected primary crime type.
# Index(['case_number', 'id', 'date', 'block', 'iucr', 'primary_type',
#        'description', 'location_description', 'domestic', 'beat', 'district',
#        'ward', 'community_area', 'fbi_code', 'year', 'updated_on',
#        'x_coordinate', 'y_coordinate', 'latitude', 'longitude', 'time',
#        'month', 'day', 'day_of_week', 'day_of_year', 'hour', 'minute',
#        'hour_sin', 'hour_cos', 'day_of_week_sin', 'day_of_week_cos',
#        'month_sin', 'month_cos', 'day_of_year_sin', 'day_of_year_cos',
#        'at_least_one_arrested', 'people_involved', 'arrest'],
#       dtype='str')

# %%
theft_df.head()
# Out:
#   case_number       id        date                 block  iucr primary_type  \
# 0      121135  3750199  2005-01-12     031XX W CERMAK RD  0820        THEFT
# 1     C016585  8386829  2011-01-14       031XX W 15TH ST  0820        THEFT
# 2     C431426  8095885  2011-06-04  004XX E OAKWOOD BLVD  0820        THEFT
# 3     C507773  8095878  2011-06-04    055XX S WABASH AVE  0820        THEFT
# 4     G061706  1985069  2002-01-30    083XX S INDIANA AV  0820        THEFT
#
#       description location_description  domestic  beat  ...  hour_cos  \
# 0  $500 AND UNDER               STREET     False  1033  ... -0.707107
# 1  $500 AND UNDER            RESIDENCE     False  1022  ... -0.965926
# 2  $500 AND UNDER          HOTEL/MOTEL     False   213  ... -0.965926
# 3  $500 AND UNDER            RESIDENCE     False   233  ... -0.965926
# 4  $500 AND UNDER                OTHER     False   632  ... -0.965926
#
#    day_of_week_sin  day_of_week_cos     month_sin  month_cos day_of_year_sin  \
# ...
